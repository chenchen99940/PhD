# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

    
    
    
def Belief(State,p,r):
   
    equilibrium = r/(1-p+r);
    
    if State[0]== 0 and State[1]> 0:
            Belief = (r-r*(p-r)**(State[1]))/(1+r-p);
    elif State[0]== 1 and State[1]> 0:
            Belief = (r+(1-p)*(p-r)**(State[1]))/(1+r-p);
            
    else:
        
        Belief = equilibrium;

    return Belief;
            
        
def WhittleIndex(State,p,r):
    WhittleIndex = 0.;

    
    if State[0]== 0 and State[1]>0:
        l= State[1];
        x= Belief([0,l],p,r);
        y=Belief([0,l+1],p,r);
        WhittleIndex =((x-y)*(l+1)+y)/(1-p+(x-y)*l+y); 
    elif State[0] == 1:
        WhittleIndex = r/((1-p)*(1+r-p)+r);
    
    else:
        WhittleIndex = r/((1-p)*(1+r-p)+r);
            
    return WhittleIndex;

def update(S,C,Reward,alpha,p,r,q,s,gamma,N):
        #the update process of each timestep.
        
        #S is the list of belief states of all channels.
        #C is the list of actual channel states.
        W = [0.]*N;
        Y = [0.]*N;
        Action = [0]*N;
        Threshold = 0.;
        Seed = np.random.rand(N);
        
       #Get the Threshold. 
        for i in range(int(N*gamma)):
            Y[i]= WhittleIndex(S[i],p,r);
        for i in range(int(N*gamma),N):
            Y[i]= WhittleIndex(S[i],q,s);
        
        Y.sort();
        Threshold = Y[int((1-alpha)*N)];
        
        
        
       #Get the Action vector.
        for i in range(int(N*gamma)):
            W[i]= WhittleIndex(S[i],p,r);
        for i in range(int(N*gamma),N):
            W[i]= WhittleIndex(S[i],q,s);
    
        h=0;
        for i in range(N):
            if W[i]>= Threshold:
                Action[i]=1;
                h=h+1;
            if h >= alpha*N:
                break;
            
       #The update process.
       
        for i in range(int(N*gamma)):
        
            if Action[i] == 0 and S[i][1]>0:
                S[i][1]= S[i][1]+1;
                if C[i]==0:
                    if Seed[i]<r:
                        C[i]=1;
                    else:
                        C[i]=0;
                else:
                    if Seed[i]<p:
                        C[i]=1;
                    else:
                        C[i]=0;
                
                
                
               
             
            elif Action[i] == 0 and S[i][1]==0:
                if C[i]==0:
                    if Seed[i]<r:
                        C[i]=1;
                    else:
                        C[i]=0;
                else: 
                    if Seed[i]<p:
                        C[i]=1;
                    else:
                        C[i]=0;
            
            else:
                if C[i]==1:
                    S[i]= [1,1];
                    Reward = Reward + 1;
                    C[i]= int((Seed[i]<p)==True);
                    
                else:
                    S[i]= [0,1];
                    C[i]= int((Seed[i]<r)==True);
        
        for i in range(int(N*gamma),N):
        
            if Action[i] == 0 and S[i][1]>0:
                S[i][1]= S[i][1]+1;
                if C[i]==0:
                    if Seed[i]<s:
                        C[i]=1;
                    else:
                        C[i]=0;
                else:
                    if Seed[i]<q:
                        C[i]=1;
                    else:
                        C[i]=0;
                
                
                
               
             
            elif Action[i] == 0 and S[i][1]==0:
                if C[i]==0:
                    if Seed[i]<s:
                        C[i]=1;
                    else:
                        C[i]=0;
                else: 
                    if Seed[i]<q:
                        C[i]=1;
                    else:
                        C[i]=0;
            
            else:
                if C[i]==1:
                    S[i]= [1,1];
                    Reward = Reward + 1;
                    C[i]= int((Seed[i]<q)==True);
                    
                else:
                    S[i]= [0,1];
                    C[i]= int((Seed[i]<s)==True);
        
        
        
        return Reward;

# %%
def onetrial(S,C,Reward,timesteps,alpha,p,r,q,s,gamma,N):

    for i in range(timesteps):
        Reward = update(S,C,Reward,alpha,p,r,q,s,gamma,N);
    return Reward;

# %%
import numpy as np

class Parameters:
    
    def __init__(self,timesteps,alpha,p,r,q,s,gamma,N):
        self.timesteps = timesteps;
        self.alpha = alpha;
        self.p = p
        self.r = r
        self.q = q
        self.s = s
        self.gamma = gamma
        self.N = N
    
    def fileName(self):
        
        return 'output/CI_Demo_{}_{}_{}_{}_{}_{}_{}_{}.npy'.format(self.timesteps,self.alpha,self.p,self.r,self.q,self.s,self.gamma,self.N)
    
def simulate(parameters):
    
    return onetrial([[0,0]]*parameters.N,[0]*parameters.N,0,parameters.timesteps,parameters.alpha,parameters.p,parameters.r,parameters.q,parameters.s,parameters.gamma,parameters.N);


def computeAndSave(parameters,number_of_replicas_to_compute):
    
    fileName = parameters.fileName();
    sum_of_results = 0;
    sum_of_squares = 0;
    number_computed = 0;
    
    try:
        print('file',fileName,'exists')
        sum_of_results,sum_of_squares,number_computed = np.load(fileName)
        
    except Exception as e:
        print(e);
        
    if number_computed < number_of_replicas_to_compute:
        print('We should do more computations');
        for n in range(number_computed,number_of_replicas_to_compute):
            result = simulate(parameters)
            sum_of_results += result
            sum_of_squares += result**2
            
        np.save(fileName,np.array([sum_of_results,sum_of_squares,number_of_replicas_to_compute]))
        
        number_computed = number_of_replicas_to_compute;
        
    print('all computation done for',parameters.fileName())
        
    average = 100*sum_of_results / (number_computed*parameters.N*parameters.timesteps)
    confidence = 100*(np.sqrt((sum_of_squares / number_computed-average**2)/number_computed))/(parameters.N*parameters.timesteps)
        
    return average,confidence

# %%
from multiprocessing import Pool

A = [0]*100;
C = [0]*100;

def worker(n):
    return computeAndSave(Parameters(500,0.3,0.75,0.2,0.8,0.3,0.6,n),10000)

num_processors = 16;
p=Pool(processes = num_processors);

t = list(range(5,505,5));

X = p.map(worker,t)

for i in range(100):
    A[i] = X[i][0]
    C[i] = X[i][1]

return A,C;
# Out:
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_15.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_5.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_45.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_25.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_35.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_85.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_55.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_75.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_65.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_95.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_115.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_105.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_125.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_135.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_155.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_145.npy exists
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_5.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_15.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_35.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_45.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_55.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_25.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_95.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_85.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_65.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_115.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_135.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_155.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_75.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_105.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_50.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_30.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_40.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_10.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_90.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_70.npy exists
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_145.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_120.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_60.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_160.npy exists
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_125.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_100.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_110.npy exists
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_50.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_80.npy exists
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_40.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_20.npy exists
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_10.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_140.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_150.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_130.npy exists
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_70.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_60.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_30.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_165.npy exists
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_120.npy
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_140.npy'
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_175.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_130.npy'
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_100.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_185.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_160.npy'
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_20.npy
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_110.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_195.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_245.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_150.npy'
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_205.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_225.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_215.npy exists
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_185.npy
# We should do more computations
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_235.npy exists
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_195.npy
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_175.npy
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_80.npy
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_225.npy'
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_255.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_190.npy exists
# We should do more computations
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_215.npy'
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_235.npy'
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_165.npy
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_205.npy'
# We should do more computations
# We should do more computations
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_245.npy'
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_255.npy'
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_190.npy'
# We should do more computations
# We should do more computations
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_180.npy exists
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_90.npy
# We should do more computations
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_170.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_275.npy exists
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_200.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_275.npy'
# We should do more computations
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_200.npy'
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_265.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_265.npy'
# We should do more computations
# We should do more computations
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_180.npy'
# We should do more computations
# We should do more computations
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_170.npy'
# We should do more computations
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_130.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_285.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_285.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_140.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_295.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_295.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_150.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_305.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_305.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_160.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_315.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_315.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_170.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_325.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_325.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_180.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_335.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_335.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_190.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_345.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_345.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_200.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_355.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_355.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_205.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_210.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_210.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_215.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_220.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_220.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_225.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_230.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_230.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_235.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_240.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_240.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_245.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_250.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_250.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_255.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_260.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_260.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_265.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_270.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_270.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_275.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_280.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_280.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_285.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_290.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_290.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_210.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_365.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_365.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_295.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_300.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_300.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_220.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_375.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_375.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_305.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_310.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_310.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_230.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_385.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_385.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_315.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_320.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_320.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_240.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_395.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_395.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_250.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_405.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_405.npy'
# We should do more computations
# all computation done for output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_325.npy
# file output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_330.npy exists
# [Errno 2] No such file or directory: 'output/CI_Demo_500_0.3_0.75_0.2_0.8_0.3_0.6_330.npy'
# We should do more computations
